# %% [markdown]
# # **Imports**

# %%
import pandas as pd
from openpyxl import load_workbook
from dataclasses import dataclass
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # **Functions**

# %%
def get_sheetnames_xlsx(filepath):
    wb = load_workbook(filepath, read_only=True, keep_links=False)
    return wb.sheetnames

# %% [markdown]
# # **Constants**

# %%
@dataclass(frozen=True)
class Pathes:
    path: str = '../main_datasets/10. ДЖКХ + ДИТ/12. Класс энергоэффективности соцобъектов.xlsx'
    path_processed: str = '../main_datasets/processed_datasets/'

# %% [markdown]
# # **Load dataset**

# %%
sheets_list = get_sheetnames_xlsx(Pathes.path)
sheets_list
# Out:
# ['report']

# %%
table = pd.read_excel(Pathes.path, engine='openpyxl', sheet_name=sheets_list[0])

# %%
table.head(10)
# Out:
#                                          Департамент  Всего строений  \
# 0                        Административное учреждение             NaN
# 1                                             Здание             NaN
# 2     Департамент городского имущества города Москвы            23.0
# 3  Государственное бюджетное учреждение города Мо...             1.0
# 4                       ул. Якиманка Б. д. 38 стр. А             NaN
# 5  Государственное бюджетное учреждение города Мо...            10.0
# 6                 пер. Гнездниковский М. д. 9 стр. 6             NaN
# 7                 пер. Гнездниковский М. д. 9 стр. 7             NaN
# 8                            пер. Факультетский д. 6             NaN
# 9                            пл. Преображенская д. 4             NaN
#
#    Общая площадь, м²  Отапливаемая площадь, м²  \
# 0                NaN                       NaN
# 1                NaN                       NaN
# 2            28766.1                   28755.9
# ...

# %%
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 16798    False
# 16799     True
# 16800    False
# 16801     True
# 16802     True
# Name: Всего строений, Length: 16803, dtype: bool

# %%
table['Департамент'].loc[np.logical_not(table['Всего строений'].isna())].to_list()
# Out:
# ['Департамент городского имущества города Москвы',
#  'Государственное бюджетное учреждение города Москвы "Городской центр имущественных платежей"',
#  'Государственное бюджетное учреждение города Москвы Московское городское бюро технической инвентаризации',
#  'Государственное казенное учреждение города Москвы "Московский центр недвижимости"',
#  'Департамент городского имущества города Москвы',
#  'Департамент градостроительной политики города Москвы',
#  'Государственное бюджетное учреждение города Москвы "Информационно-аналитический центр комплекса градостроительной политики и строительства города Москвы "Мосстройинформ"',
#  'Государственное бюджетное учреждение города Москвы "Московский центр обеспечения развития строительной отрасли на Яблочкова"',
#  'Департамент жилищно-коммунального хозяйства',
#  'Акционерное общество "Мосводоканал"',
#  'Акционерное общество "Мослифт"',
#  'Акционерное общество "Экотехпром"',
#  'АО "Москоллектор"',
#  'ГБУ "Автомобильные дороги СВАО"',
# ...
